# %% [markdown]
# # Proyek: Air Quality Predictive Analytics

# %% [markdown]
# # Latar Belakang

# %% [markdown]
# Kualitas udara menjadi salah satu indikator penting dalam menjaga kesehatan masyarakat dan kelestarian lingkungan, terutama di daerah perkotaan yang padat penduduk dan memiliki tingkat polusi yang tinggi. Peningkatan aktivitas manusia, seperti transportasi, industri, dan pembakaran bahan bakar fosil, berkontribusi signifikan terhadap pencemaran udara. Hal ini menyebabkan peningkatan konsentrasi polutan seperti CO, PM10, PM2.5, O₃, dan NO₂, yang secara langsung memengaruhi kesehatan manusia dan lingkungan.
#
# Beberapa isu utama yang melatarbelakangi pentingnya proyek ini:
# 1. Dampak Kesehatan:
# Paparan polutan udara dapat menyebabkan berbagai masalah kesehatan, termasuk penyakit pernapasan, kardiovaskular, dan bahkan kematian dini. World Health Organization (WHO) telah menyatakan bahwa kualitas udara yang buruk merupakan salah satu ancaman kesehatan global.
# 2. Dampak Lingkungan:
# Polutan seperti ozon dan nitrogen dioksida tidak hanya berdampak pada kesehatan manusia tetapi juga menyebabkan kerusakan lingkungan, seperti penurunan kualitas tanah dan air serta gangguan ekosistem.

# %% [markdown]
# # Business Understanding

# %% [markdown]
# ## Problem Statements

# %% [markdown]
# Dengan meningkatnya polusi udara di daerah perkotaan, diperlukan sistem yang dapat memprediksi kualitas udara.

# %% [markdown]
# ## Goals

# %% [markdown]
# Memprediksi nilai AQI (Air Quality Index) berdasarkan parameter polusi udara menggunakan machine learning.

# %% [markdown]
# ## Solutions

# %% [markdown]
# 1. Pemrosesan Data:
# Melakukan normalisasi menggunakan metode Min-Max Scaling untuk memastikan semua parameter berada dalam skala yang sama.
# Membagi data menjadi subset pelatihan dan validasi untuk menghindari overfitting.
# 2. Pemilihan Model:
# Menggunakan model Neural Networks (CNN + LSTM) untuk menangkap pola temporal.
# Memanfaatkan teknik dropout untuk menghindari overfitting.
# 3. Evaluasi Model:
# Menggunakan Mean Absolute Error (MAE) sebagai metrik evaluasi utama.
# Membandingkan prediksi model dengan data aktual melalui visualisasi.

# %% [markdown]
# # Datasets

# %% [markdown]
# Dataset yang digunakan berisi data kualitas udara harian Chicago-Naperville-Elgin, IL-IN-WI dari tahun 2015-2024 dengan fitur-fitur sebagai berikut:
# - Overall AQI Value: Indeks kualitas udara yang mencerminkan tingkat risiko kesehatan.
# - CO (Karbon Monoksida): Konsentrasi gas CO dalam udara.
# - Ozon (O₃): Konsentrasi gas ozon.
# - PM10: Partikel udara dengan diameter ≤ 10 µm.
# - PM2.5: Partikel udara dengan diameter ≤ 2.5 µm.
# - NO₂ (Nitrogen Dioksida): Konsentrasi gas nitrogen dioksida.
#
# Sumber dataset : https://www.epa.gov/outdoor-air-quality-data/air-quality-index-daily-values-report

# %% [markdown]
# # Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import Dense, LSTM, Bidirectional, Conv1D

# %% [markdown]
# # Load Data

# %%
df = pd.read_csv('aqidaily.csv', sep=';')

df
# Out:
#             Date  Overall AQI Value Main Pollutant  \
# 0       1/1/2015                 49          PM2.5
# 1       1/2/2015                 60          PM2.5
# 2       1/3/2015                 71          PM2.5
# 3       1/4/2015                 71          PM2.5
# 4       1/5/2015                 52          PM2.5
# ...          ...                ...            ...
# 3629   12/8/2024                 48          PM2.5
# 3630   12/9/2024                 49          PM2.5
# 3631  12/10/2024                 52          PM2.5
# 3632  12/11/2024                 39          PM2.5
# 3633  12/12/2024                 42          PM2.5
#
#                              Site Name (of Overall AQI)  \
# 0     Gary-IITRI/ 1219.5 meters east of Tennessee St...
# 1     Gary-IITRI/ 1219.5 meters east of Tennessee St...
# 2                                  MAYFAIR PUMP STATION
# 3     Gary-IITRI/ 1219.5 meters east of Tennessee St...
# 4     Gary-IITRI/ 1219.5 meters east of Tennessee St...
# ...                                                 ...
# 3629                                      CARY GROVE HS
# 3630                                     VILLAGE GARAGE
# 3631  Gary-IITRI/ 1219.5 meters east of Tennessee St...
# 3632                                     VILLAGE GARAGE
# 3633  Gary-IITRI/ 1219.5 meters east of Tennessee St...
#
#      Site ID (of Overall AQI) Source (of Overall AQI)   CO  Ozone  PM10  PM25  \
# 0                 18-089-0022                     AQS  5.0     26    19    49
# 1                 18-089-0022                     AQS  9.0     26    19    60
# 2                 17-031-0052                     AQS  9.0     10    25    71
# 3                 18-089-0022                     AQS  8.0     31    19    71
# 4                 18-089-0022                     AQS  6.0     28    25    52
# ...                       ...                     ...  ...    ...   ...   ...
# 3629              17-111-0001                  AirNow  NaN     24    18    48
# 3630              17-031-0001                  AirNow  NaN     20    16    49
# 3631              18-089-0022                  AirNow  NaN     23    30    52
# 3632              17-031-0001                  AirNow  NaN     24    25    39
# 3633              18-089-0022                  AirNow  NaN     22    19    42
#
#        NO2
# 0     22.0
# 1     47.0
# 2     31.0
# 3     43.0
# 4     41.0
# ...    ...
# 3629   NaN
# 3630   NaN
# 3631   NaN
# 3632   NaN
# 3633   NaN
#
# [3634 rows x 11 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)
df = df.drop(columns=['Main Pollutant','Site Name (of Overall AQI)','Site ID (of Overall AQI)','Source (of Overall AQI)'])
df.head()
# Out:
#             Overall AQI Value   CO  Ozone  PM10  PM25   NO2
# Date
# 2015-01-01                 49  5.0     26    19    49  22.0
# 2015-01-02                 60  9.0     26    19    60  47.0
# 2015-01-03                 71  9.0     10    25    71  31.0
# 2015-01-04                 71  8.0     31    19    71  43.0
# 2015-01-05                 52  6.0     28    25    52  41.0

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Info Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3634 entries, 2015-01-01 to 2024-12-12
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Overall AQI Value  3634 non-null   int64
#  1   CO                 3535 non-null   float64
#  2   Ozone              3634 non-null   int64
#  3   PM10               3634 non-null   int64
#  4   PM25               3634 non-null   int64
#  5   NO2                3592 non-null   float64
# dtypes: float64(2), int64(4)
# memory usage: 198.7 KB

# %%
df.describe()
# Out:
#        Overall AQI Value           CO        Ozone         PM10         PM25  \
# count        3634.000000  3535.000000  3634.000000  3634.000000  3634.000000
# mean           64.207210     5.742574    46.587507    32.078426    58.006054
# std            21.900288     2.913570    25.624148    15.102190    15.023515
# min            24.000000     0.000000    10.000000     5.000000    22.000000
# 25%            52.000000     3.000000    31.000000    21.000000    51.000000
# 50%            59.000000     5.000000    40.000000    29.000000    57.000000
# 75%            70.000000     7.000000    49.000000    41.000000    64.000000
# max           246.000000    24.000000   197.000000   117.000000   246.000000
#
#                NO2
# count  3592.000000
# mean     33.318486
# std      11.017437
# min       7.000000
# 25%      26.000000
# 50%      32.000000
# 75%      40.000000
# max      96.000000

# %% [markdown]
# ## Checking Missing Value

# %%
# Mengecek missing values
print(df.isnull().sum())
# Out:
# Overall AQI Value     0
# CO                   99
# Ozone                 0
# PM10                  0
# PM25                  0
# NO2                  42
# dtype: int64

# %% [markdown]
# ## Checking Outliers

# %%
# Boxplot untuk setiap fitur
plt.figure(figsize=(10, 6))
sns.boxplot(data=df[['CO', 'Ozone', 'PM10', 'PM25', 'NO2', 'Overall AQI Value']])
plt.title('Outliers Check')
plt.show()

# %%
for col in ['CO', 'Ozone', 'PM10', 'PM25', 'NO2', 'Overall AQI Value']:
    plt.figure(figsize=(8, 4))
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.show()

# %%
# Korelasi fitur dengan AQI
corr = df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Feature Correlation with Overall AQI Value')
plt.show()

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Handling Missing Value

# %%
df.interpolate(method='time', inplace=True)  # Interpolasi berdasarkan waktu

# Mengecek missing values
print(df.isnull().sum())
# Out:
# Overall AQI Value    0
# CO                   0
# Ozone                0
# PM10                 0
# PM25                 0
# NO2                  0
# dtype: int64

# %% [markdown]
# ## Handling Outliers

# %%
df['PM25'] = np.clip(df['PM25'], df['PM25'].quantile(0.01), df['PM25'].quantile(0.99))
df['Overall AQI Value'] = np.clip(df['Overall AQI Value'], df['Overall AQI Value'].quantile(0.01), df['Overall AQI Value'].quantile(0.99))
df['Ozone'] = np.clip(df['Ozone'], df['Ozone'].quantile(0.01), df['Ozone'].quantile(0.99))
df['PM10'] = np.clip(df['PM10'], df['PM10'].quantile(0.01), df['PM10'].quantile(0.99))

# %%
# Boxplot untuk setiap fitur
plt.figure(figsize=(10, 6))
sns.boxplot(data=df[['CO', 'Ozone', 'PM10', 'PM25', 'NO2', 'Overall AQI Value']])
plt.title('Outliers Check')
plt.show()

# %% [markdown]
# ## Normalisasi Data

# %%
def normalize_series(data, min, max):
    # Normalisasi data dengan formula (data - min) / (max - min)
    data = (data - min) / (max - min)
    return data

# %%
data =df.values

data_norm = normalize_series(data, data.min(axis=0), data.max(axis=0))
data_norm
# Out:
# array([[0.13559322, 0.20833333, 0.06899021, 0.15384615, 0.26760563,
#         0.16853933],
#        [0.22881356, 0.375     , 0.06899021, 0.15384615, 0.42253521,
#         0.4494382 ],
#        [0.3220339 , 0.375     , 0.        , 0.24615385, 0.57746479,
#         0.26966292],
#        ...,
#        [0.16101695, 0.20833333, 0.04511817, 0.32307692, 0.30985915,
#         0.17977528],
#        [0.05084746, 0.20833333, 0.05307552, 0.24615385, 0.12676056,
#         0.17977528],
#        [0.07627119, 0.20833333, 0.03716082, 0.15384615, 0.16901408,
#         0.17977528]])

# %% [markdown]
# ## Split Data

# %%
split_time = int(len(data_norm) * 0.8)

x_train = data_norm[:split_time]
x_valid = data_norm[split_time:]

print('train : ', len(x_train))
print('validation : ', len(x_valid))
# Out:
# train :  2907
# validation :  727

# %% [markdown]
# # Modeling

# %%
def windowed_dataset(series, batch_size, n_past=31, n_future=31, shift=1):
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(size=(n_past + n_future), shift = shift, drop_remainder = True)
    ds = ds.flat_map(lambda w: w.batch(n_past + n_future))
    ds = ds.shuffle(len(series))
    ds = ds.map(
        lambda w: (w[:n_past], w[n_past:])
    )
    return ds.batch(batch_size).prefetch(1)

# %%
N_FEATURES = len(df.columns)
BATCH_SIZE = 64 
N_PAST = 7
N_FUTURE = 7 
SHIFT = 1

# %%
train_set = windowed_dataset(series=x_train, 
                             batch_size=BATCH_SIZE,
                             n_past=N_PAST, 
                             n_future=N_FUTURE,
                             shift=SHIFT)

valid_set = windowed_dataset(series=x_valid, 
                             batch_size=BATCH_SIZE,
                             n_past=N_PAST, 
                             n_future=N_FUTURE,
                             shift=SHIFT)

# %%
# Membuat model
model = tf.keras.models.Sequential([
    Conv1D(filters=32, 
            kernel_size=3,
            padding="causal",
            activation="relu",
            input_shape=[N_PAST, 6],
            ),
    Bidirectional(LSTM(32, return_sequences=True)),
    Dense(64, activation="relu"),
    Dropout(0.2),
    Dense(32, activation="relu"),
    Dropout(0.3),
    Dense(8, activation="relu"),
    Dropout(0.1),
    Dense(N_FEATURES)
])

model.summary()
# Out:
# WARNING:tensorflow:From c:\Users\ThinkPad\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 7, 32)             608
#
#  bidirectional (Bidirection  (None, 7, 64)             16640
#  al)
#
#  dense (Dense)               (None, 7, 64)             4160
#
#  dropout (Dropout)           (None, 7, 64)             0
#
#  dense_1 (Dense)             (None, 7, 32)             2080
#
#  dropout_1 (Dropout)         (None, 7, 32)             0
#
#  dense_2 (Dense)             (None, 7, 8)              264
#
#  dropout_2 (Dropout)         (None, 7, 8)              0
#
#  dense_3 (Dense)             (None, 7, 6)              54
#
# =================================================================
# Total params: 23806 (92.99 KB)
# Trainable params: 23806 (92.99 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile model
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss='mae', optimizer=optimizer, metrics=['mae'])

# %%
# ModelCheckpoint
cp_path = 'model/my_model.h5'
checkpoint = ModelCheckpoint(cp_path, save_weights_only=True, save_best_only=True, monitor='val_loss', verbose=1)

# %%
# Training
history = model.fit(train_set, 
                validation_data=valid_set, 
                epochs=100, 
                callbacks=[checkpoint])
# Out:
# Epoch 1/100
# WARNING:tensorflow:From c:\Users\ThinkPad\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\ThinkPad\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
#      42/Unknown - 8s 13ms/step - loss: 0.2892 - mae: 0.2892
# Epoch 1: val_loss improved from inf to 0.26637, saving model to model\my_model.h5
# 46/46 [==============================] - 10s 59ms/step - loss: 0.2883 - mae: 0.2883 - val_loss: 0.2664 - val_mae: 0.2664
# Epoch 2/100
# 43/46 [===========================>..] - ETA: 0s - loss: 0.2561 - mae: 0.2561
# Epoch 2: val_loss improved from 0.26637 to 0.22985, saving model to model\my_model.h5
# 46/46 [==============================] - 2s 24ms/step - loss: 0.2553 - mae: 0.2553 - val_loss: 0.2298 - val_mae: 0.2298
# Epoch 3/100
# 44/46 [===========================>..] - ETA: 0s - loss: 0.2314 - mae: 0.2314
# Epoch 3: val_loss improved from 0.22985 to 0.21218, saving model to model\my_model.h5
# 46/46 [==============================] - 2s 26ms/step - loss: 0.2315 - mae: 0.2315 - val_loss: 0.2122 - val_mae: 0.2122
# Epoch 4/100
# 44/46 [===========================>..] - ETA: 0s - loss: 0.2200 - mae: 0.2200
# Epoch 4: val_loss improved from 0.21218 to 0.20459, saving model to model\my_model.h5
# 46/46 [==============================] - 2s 34ms/step - loss: 0.2201 - mae: 0.2201 - val_loss: 0.2046 - val_mae: 0.2046
# Epoch 5/100
# 45/46 [============================>.] - ETA: 0s - loss: 0.2129 - mae: 0.2129
# Epoch 5: val_loss improved from 0.20459 to 0.19767, saving model to model\my_model.h5
# 46/46 [==============================] - 2s 34ms/step - loss: 0.2128 - mae: 0.2128 - val_loss: 0.1977 - val_mae: 0.1977
# Epoch 6/100
# 45/46 [============================>.] - ETA: 0s - loss: 0.2064 - mae: 0.2064
# Epoch 6: val_loss improved from 0.19767 to 0.19097, saving model to model\my_model.h5
# 46/46 [==============================] - 2s 27ms/step - loss: 0.2064 - mae: 0.2064 - val_loss: 0.1910 - val_mae: 0.1910
# Epoch 7/100
# 46/46 [==============================] - ETA: 0s - loss: 0.1994 - mae: 0.1994
# Epoch 7: val_loss improved from 0.19097 to 0.18313, saving model to model\my_model.h5
# 46/46 [==============================] - 2s 33ms/step - loss: 0.1994 - mae: 0.1994 - val_loss: 0.1831 - val_mae: 0.1831
# Epoch 8/100
# 41/46 [=========================>....] - ETA: 0s - loss: 0.1929 - mae: 0.1929
# Epoch 8: val_loss improved from 0.18313 to 0.17744, saving model to model\my_model.h5
# 46/46 [==============================] - 1s 18ms/step - loss: 0.1932 - mae: 0.1932 - val_loss: 0.1774 - val_mae: 0.1774
# Epoch 9/100
# 41/46 [=========================>....] - ETA: 0s - loss: 0.1877 - mae: 0.1877
# Epoch 9: val_loss improved from 0.17744 to 0.17215, saving model to model\my_model.h5
# 46/46 [==============================] - 2s 20ms/step - loss: 0.1877 - mae: 0.1877 - val_loss: 0.1722 - val_mae: 0.1722
# Epoch 10/100
# 45/46 [============================>.] - ETA: 0s - loss: 0.1825 - mae: 0.1825
# Epoch 10: val_loss improved from 0.17215 to 0.16768, saving model to model\my_model.h5
# 46/46 [==============================] - 3s 40ms/step - loss: 0.1826 - mae: 0.1826 - val_loss: 0.1677 - val_mae: 0.1677
# Epoch 11/100
# 43/46 [===========================>..] - ETA: 0s - loss: 0.1782 - mae: 0.1782
# Epoch 11: val_loss improved from 0.16768 to 0.16384, saving model to model\my_model.h5
# 46/46 [==============================] - 2s 21ms/step - loss: 0.1781 - mae: 0.1781 - val_loss: 0.1638 - val_mae: 0.1638
# Epoch 12/100
# 45/46 [============================>.] - ETA: 0s - loss: 0.1735 - mae: 0.1735
# Epoch 12: val_loss improved from 0.16384 to 0.15977, saving model to model\my_model.h5
# 46/46 [==============================] - 2s 21ms/step - loss: 0.1735 - mae: 0.1735 - val_loss: 0.1598 - val_mae: 0.1598
# Epoch 13/100
# 46/46 [==============================] - ETA: 0s - loss: 0.1697 - mae: 0.1697
# Epoch 13: val_loss improved from 0.15977 to 0.15605, saving model to model\my_model.h5
# 46/46 [==============================] - 1s 20ms/step - loss: 0.1697 - mae: 0.1697 - val_loss: 0.1560 - val_mae: 0.1560
# Epoch 14/100
# 45/46 [============================>.] - ETA: 0s - loss: 0.1657 - mae: 0.1657
# Epoch 14: val_loss improved from 0.15605 to 0.15332, saving model to model\my_model.h5
# 46/46 [==============================] - 2s 24ms/step - loss: 0.1656 - mae: 0.1656 - val_loss: 0.1533 - val_mae: 0.1533
# Epoch 15/100
# 46/46 [==============================] - ETA: 0s - loss: 0.1626 - mae: 0.1626
# Epoch 15: val_loss improved from 0.15332 to 0.15088, saving model to model\my_model.h5
# 46/46 [==============================] - 1s 21ms/step - loss: 0.1626 - mae: 0.1626 - val_loss: 0.1509 - val_mae: 0.1509
# Epoch 16/100
# 43/46 [===========================>..] - ETA: 0s - loss: 0.1591 - mae: 0.1591
# Epoch 16: val_loss improved from 0.15088 to 0.14759, saving model to model\my_model.h5
# 46/46 [==============================] - 2s 22ms/step - loss: 0.1592 - mae: 0.1592 - val_loss: 0.1476 - val_mae: 0.1476
# Epoch 17/100
# 42/46 [==========================>...] - ETA: 0s - loss: 0.1563 - mae: 0.1563
# Epoch 17: val_loss improved from 0.14759 to 0.14510, saving model to model\my_model.h5
# 46/46 [==============================] - 1s 19ms/step - loss: 0.1563 - mae: 0.1563 - val_loss: 0.1451 - val_mae: 0.1451
# Epoch 18/100
# 44/46 [===========================>..] - ETA: 0s - loss: 0.1537 - mae: 0.1537
# Epoch 18: val_loss improved from 0.14510 to 0.14288, saving model to model\my_model.h5
# 46/46 [==============================] - 2s 36ms/step - loss: 0.1537 - mae: 0.1537 - val_loss: 0.1429 - val_mae: 0.1429
# Epoch 19/100
# 45/46 [============================>.] - ETA: 0s - loss: 0.1513 - mae: 0.1513
# Epoch 19: val_loss improved from 0.14288 to 0.14199, saving model to model\my_model.h5
# 46/46 [==============================] - 3s 47ms/step - loss: 0.1513 - mae: 0.1513 - val_loss: 0.1420 - val_mae: 0.1420
# Epoch 20/100
# 44/46 [===========================>..] - ETA: 0s - loss: 0.1494 - mae: 0.1494
# Epoch 20: val_loss improved from 0.14199 to 0.14017, saving model to model\my_model.h5
# 46/46 [==============================] - 2s 33ms/step - loss: 0.1494 - mae: 0.1494 - val_loss: 0.1402 - val_mae: 0.1402
# Epoch 21/100
# 45/46 [============================>.] - ETA: 0s - loss: 0.1478 - mae: 0.1478
# Epoch 21: val_loss improved from 0.14017 to 0.13840, saving model to model\my_model.h5
# 46/46 [==============================] - 2s 34ms/step - loss: 0.1479 - mae: 0.1479 - val_loss: 0.1384 - val_mae: 0.1384
# Epoch 22/100
# 46/46 [==============================] - ETA: 0s - loss: 0.1454 - mae: 0.1454
# Epoch 22: val_loss improved from 0.13840 to 0.13805, saving model to model\my_model.h5
# 46/46 [==============================] - 2s 30ms/step - loss: 0.1454 - mae: 0.1454 - val_loss: 0.1381 - val_mae: 0.1381
# Epoch 23/100
# 41/46 [=========================>....] - ETA: 0s - loss: 0.1436 - mae: 0.1436
# Epoch 23: val_loss improved from 0.13805 to 0.13593, saving model to model\my_model.h5
# 46/46 [==============================] - 2s 23ms/step - loss: 0.1435 - mae: 0.1435 - val_loss: 0.1359 - val_mae: 0.1359
# Epoch 24/100
# 43/46 [===========================>..] - ETA: 0s - loss: 0.1413 - mae: 0.1413
# Epoch 24: val_loss improved from 0.13593 to 0.13463, saving model to model\my_model.h5
# 46/46 [==============================] - 2s 27ms/step - loss: 0.1417 - mae: 0.1417 - val_loss: 0.1346 - val_mae: 0.1346
# Epoch 25/100
# 44/46 [===========================>..] - ETA: 0s - loss: 0.1403 - mae: 0.1403
# Epoch 25: val_loss improved from 0.13463 to 0.13433, saving model to model\my_model.h5
# 46/46 [==============================] - 2s 27ms/step - loss: 0.1405 - mae: 0.1405 - val_loss: 0.1343 - val_mae: 0.1343
# Epoch 26/100
# 45/46 [============================>.] - ETA: 0s - loss: 0.1395 - mae: 0.1395
# Epoch 26: val_loss improved from 0.13433 to 0.13287, saving model to model\my_model.h5
# 46/46 [==============================] - 2s 31ms/step - loss: 0.1394 - mae: 0.1394 - val_loss: 0.1329 - val_mae: 0.1329
# Epoch 27/100
# 44/46 [===========================>..] - ETA: 0s - loss: 0.1376 - mae: 0.1376
# Epoch 27: val_loss did not improve from 0.13287
# 46/46 [==============================] - 1s 17ms/step - loss: 0.1377 - mae: 0.1377 - val_loss: 0.1332 - val_mae: 0.1332
# Epoch 28/100
# 45/46 [============================>.] - ETA: 0s - loss: 0.1367 - mae: 0.1367
# Epoch 28: val_loss improved from 0.13287 to 0.13158, saving model to model\my_model.h5
# 46/46 [==============================] - 2s 29ms/step - loss: 0.1368 - mae: 0.1368 - val_loss: 0.1316 - val_mae: 0.1316
# Epoch 29/100
# 43/46 [===========================>..] - ETA: 0s - loss: 0.1349 - mae: 0.1349
# Epoch 29: val_loss improved from 0.13158 to 0.13105, saving model to model\my_model.h5
# 46/46 [==============================] - 2s 19ms/step - loss: 0.1349 - mae: 0.1349 - val_loss: 0.1311 - val_mae: 0.1311
# Epoch 30/100
# 42/46 [==========================>...] - ETA: 0s - loss: 0.1343 - mae: 0.1343
# Epoch 30: val_loss improved from 0.13105 to 0.13076, saving model to model\my_model.h5
# 46/46 [==============================] - 1s 19ms/step - loss: 0.1345 - mae: 0.1345 - val_loss: 0.1308 - val_mae: 0.1308
# Epoch 31/100
# 45/46 [============================>.] - ETA: 0s - loss: 0.1337 - mae: 0.1337
# Epoch 31: val_loss improved from 0.13076 to 0.13059, saving model to model\my_model.h5
# 46/46 [==============================] - 1s 18ms/step - loss: 0.1336 - mae: 0.1336 - val_loss: 0.1306 - val_mae: 0.1306
# Epoch 32/100
# 43/46 [===========================>..] - ETA: 0s - loss: 0.1327 - mae: 0.1327
# Epoch 32: val_loss improved from 0.13059 to 0.12998, saving model to model\my_model.h5
# 46/46 [==============================] - 1s 18ms/step - loss: 0.1327 - mae: 0.1327 - val_loss: 0.1300 - val_mae: 0.1300
# Epoch 33/100
# 43/46 [===========================>..] - ETA: 0s - loss: 0.1318 - mae: 0.1318
# Epoch 33: val_loss improved from 0.12998 to 0.12978, saving model to model\my_model.h5
# 46/46 [==============================] - 1s 20ms/step - loss: 0.1320 - mae: 0.1320 - val_loss: 0.1298 - val_mae: 0.1298
# Epoch 34/100
# 46/46 [==============================] - ETA: 0s - loss: 0.1309 - mae: 0.1309
# Epoch 34: val_loss improved from 0.12978 to 0.12933, saving model to model\my_model.h5
# 46/46 [==============================] - 1s 20ms/step - loss: 0.1309 - mae: 0.1309 - val_loss: 0.1293 - val_mae: 0.1293
# Epoch 35/100
# 43/46 [===========================>..] - ETA: 0s - loss: 0.1300 - mae: 0.1300
# Epoch 35: val_loss improved from 0.12933 to 0.12889, saving model to model\my_model.h5
# 46/46 [==============================] - 1s 21ms/step - loss: 0.1299 - mae: 0.1299 - val_loss: 0.1289 - val_mae: 0.1289
# Epoch 36/100
# 45/46 [============================>.] - ETA: 0s - loss: 0.1297 - mae: 0.1297
# Epoch 36: val_loss improved from 0.12889 to 0.12878, saving model to model\my_model.h5
# 46/46 [==============================] - 1s 18ms/step - loss: 0.1297 - mae: 0.1297 - val_loss: 0.1288 - val_mae: 0.1288
# Epoch 37/100
# 44/46 [===========================>..] - ETA: 0s - loss: 0.1293 - mae: 0.1293
# Epoch 37: val_loss did not improve from 0.12878
# 46/46 [==============================] - 1s 20ms/step - loss: 0.1291 - mae: 0.1291 - val_loss: 0.1289 - val_mae: 0.1289
# Epoch 38/100
# 45/46 [============================>.] - ETA: 0s - loss: 0.1285 - mae: 0.1285
# Epoch 38: val_loss did not improve from 0.12878
# 46/46 [==============================] - 1s 20ms/step - loss: 0.1286 - mae: 0.1286 - val_loss: 0.1294 - val_mae: 0.1294
# Epoch 39/100
# 41/46 [=========================>....] - ETA: 0s - loss: 0.1281 - mae: 0.1281
# Epoch 39: val_loss improved from 0.12878 to 0.12830, saving model to model\my_model.h5
# 46/46 [==============================] - 2s 21ms/step - loss: 0.1283 - mae: 0.1283 - val_loss: 0.1283 - val_mae: 0.1283
# Epoch 40/100
# 45/46 [============================>.] - ETA: 0s - loss: 0.1273 - mae: 0.1273
# Epoch 40: val_loss did not improve from 0.12830
# 46/46 [==============================] - 1s 16ms/step - loss: 0.1274 - mae: 0.1274 - val_loss: 0.1284 - val_mae: 0.1284
# Epoch 41/100
# 45/46 [============================>.] - ETA: 0s - loss: 0.1271 - mae: 0.1271
# Epoch 41: val_loss did not improve from 0.12830
# 46/46 [==============================] - 2s 30ms/step - loss: 0.1272 - mae: 0.1272 - val_loss: 0.1283 - val_mae: 0.1283
# Epoch 42/100
# 43/46 [===========================>..] - ETA: 0s - loss: 0.1266 - mae: 0.1266
# Epoch 42: val_loss did not improve from 0.12830
# 46/46 [==============================] - 1s 18ms/step - loss: 0.1265 - mae: 0.1265 - val_loss: 0.1283 - val_mae: 0.1283
# Epoch 43/100
# 46/46 [==============================] - ETA: 0s - loss: 0.1259 - mae: 0.1259
# Epoch 43: val_loss improved from 0.12830 to 0.12820, saving model to model\my_model.h5
# 46/46 [==============================] - 1s 20ms/step - loss: 0.1259 - mae: 0.1259 - val_loss: 0.1282 - val_mae: 0.1282
# Epoch 44/100
# 45/46 [============================>.] - ETA: 0s - loss: 0.1258 - mae: 0.1258
# Epoch 44: val_loss improved from 0.12820 to 0.12813, saving model to model\my_model.h5
# 46/46 [==============================] - 2s 32ms/step - loss: 0.1258 - mae: 0.1258 - val_loss: 0.1281 - val_mae: 0.1281
# Epoch 45/100
# 42/46 [==========================>...] - ETA: 0s - loss: 0.1249 - mae: 0.1249
# Epoch 45: val_loss improved from 0.12813 to 0.12789, saving model to model\my_model.h5
# 46/46 [==============================] - 1s 17ms/step - loss: 0.1250 - mae: 0.1250 - val_loss: 0.1279 - val_mae: 0.1279
# Epoch 46/100
# 44/46 [===========================>..] - ETA: 0s - loss: 0.1249 - mae: 0.1249
# Epoch 46: val_loss did not improve from 0.12789
# 46/46 [==============================] - 1s 17ms/step - loss: 0.1249 - mae: 0.1249 - val_loss: 0.1281 - val_mae: 0.1281
# Epoch 47/100
# 42/46 [==========================>...] - ETA: 0s - loss: 0.1245 - mae: 0.1245
# Epoch 47: val_loss improved from 0.12789 to 0.12770, saving model to model\my_model.h5
# 46/46 [==============================] - 1s 18ms/step - loss: 0.1245 - mae: 0.1245 - val_loss: 0.1277 - val_mae: 0.1277
# Epoch 48/100
# 45/46 [============================>.] - ETA: 0s - loss: 0.1241 - mae: 0.1241
# Epoch 48: val_loss did not improve from 0.12770
# 46/46 [==============================] - 1s 14ms/step - loss: 0.1241 - mae: 0.1241 - val_loss: 0.1280 - val_mae: 0.1280
# Epoch 49/100
# 41/46 [=========================>....] - ETA: 0s - loss: 0.1241 - mae: 0.1241
# Epoch 49: val_loss improved from 0.12770 to 0.12746, saving model to model\my_model.h5
# 46/46 [==============================] - 1s 17ms/step - loss: 0.1237 - mae: 0.1237 - val_loss: 0.1275 - val_mae: 0.1275
# Epoch 50/100
# 46/46 [==============================] - ETA: 0s - loss: 0.1235 - mae: 0.1235
# Epoch 50: val_loss improved from 0.12746 to 0.12718, saving model to model\my_model.h5
# 46/46 [==============================] - 2s 31ms/step - loss: 0.1235 - mae: 0.1235 - val_loss: 0.1272 - val_mae: 0.1272
# Epoch 51/100
# 45/46 [============================>.] - ETA: 0s - loss: 0.1230 - mae: 0.1230
# Epoch 51: val_loss improved from 0.12718 to 0.12685, saving model to model\my_model.h5
# 46/46 [==============================] - 2s 31ms/step - loss: 0.1230 - mae: 0.1230 - val_loss: 0.1268 - val_mae: 0.1268
# Epoch 52/100
# 45/46 [============================>.] - ETA: 0s - loss: 0.1228 - mae: 0.1228
# Epoch 52: val_loss did not improve from 0.12685
# 46/46 [==============================] - 2s 27ms/step - loss: 0.1228 - mae: 0.1228 - val_loss: 0.1271 - val_mae: 0.1271
# Epoch 53/100
# 44/46 [===========================>..] - ETA: 0s - loss: 0.1221 - mae: 0.1221
# Epoch 53: val_loss improved from 0.12685 to 0.12666, saving model to model\my_model.h5
# 46/46 [==============================] - 2s 21ms/step - loss: 0.1222 - mae: 0.1222 - val_loss: 0.1267 - val_mae: 0.1267
# Epoch 54/100
# 45/46 [============================>.] - ETA: 0s - loss: 0.1221 - mae: 0.1221
# Epoch 54: val_loss improved from 0.12666 to 0.12664, saving model to model\my_model.h5
# 46/46 [==============================] - 2s 23ms/step - loss: 0.1220 - mae: 0.1220 - val_loss: 0.1266 - val_mae: 0.1266
# Epoch 55/100
# 43/46 [===========================>..] - ETA: 0s - loss: 0.1215 - mae: 0.1215
# Epoch 55: val_loss improved from 0.12664 to 0.12648, saving model to model\my_model.h5
# 46/46 [==============================] - 1s 18ms/step - loss: 0.1216 - mae: 0.1216 - val_loss: 0.1265 - val_mae: 0.1265
# Epoch 56/100
# 46/46 [==============================] - ETA: 0s - loss: 0.1214 - mae: 0.1214
# Epoch 56: val_loss improved from 0.12648 to 0.12616, saving model to model\my_model.h5
# 46/46 [==============================] - 2s 30ms/step - loss: 0.1214 - mae: 0.1214 - val_loss: 0.1262 - val_mae: 0.1262
# Epoch 57/100
# 46/46 [==============================] - ETA: 0s - loss: 0.1208 - mae: 0.1208
# Epoch 57: val_loss did not improve from 0.12616
# 46/46 [==============================] - 2s 23ms/step - loss: 0.1208 - mae: 0.1208 - val_loss: 0.1262 - val_mae: 0.1262
# Epoch 58/100
# 43/46 [===========================>..] - ETA: 0s - loss: 0.1206 - mae: 0.1206
# Epoch 58: val_loss improved from 0.12616 to 0.12602, saving model to model\my_model.h5
# 46/46 [==============================] - 1s 18ms/step - loss: 0.1206 - mae: 0.1206 - val_loss: 0.1260 - val_mae: 0.1260
# Epoch 59/100
# 46/46 [==============================] - ETA: 0s - loss: 0.1203 - mae: 0.1203
# Epoch 59: val_loss improved from 0.12602 to 0.12602, saving model to model\my_model.h5
# 46/46 [==============================] - 2s 40ms/step - loss: 0.1203 - mae: 0.1203 - val_loss: 0.1260 - val_mae: 0.1260
# Epoch 60/100
# 44/46 [===========================>..] - ETA: 0s - loss: 0.1198 - mae: 0.1198
# Epoch 60: val_loss improved from 0.12602 to 0.12570, saving model to model\my_model.h5
# 46/46 [==============================] - 2s 32ms/step - loss: 0.1199 - mae: 0.1199 - val_loss: 0.1257 - val_mae: 0.1257
# Epoch 61/100
# 43/46 [===========================>..] - ETA: 0s - loss: 0.1198 - mae: 0.1198
# Epoch 61: val_loss did not improve from 0.12570
# 46/46 [==============================] - 1s 17ms/step - loss: 0.1198 - mae: 0.1198 - val_loss: 0.1258 - val_mae: 0.1258
# Epoch 62/100
# 43/46 [===========================>..] - ETA: 0s - loss: 0.1197 - mae: 0.1197
# Epoch 62: val_loss improved from 0.12570 to 0.12568, saving model to model\my_model.h5
# 46/46 [==============================] - 1s 15ms/step - loss: 0.1195 - mae: 0.1195 - val_loss: 0.1257 - val_mae: 0.1257
# Epoch 63/100
# 44/46 [===========================>..] - ETA: 0s - loss: 0.1193 - mae: 0.1193
# Epoch 63: val_loss improved from 0.12568 to 0.12565, saving model to model\my_model.h5
# 46/46 [==============================] - 2s 22ms/step - loss: 0.1192 - mae: 0.1192 - val_loss: 0.1256 - val_mae: 0.1256
# Epoch 64/100
# 46/46 [==============================] - ETA: 0s - loss: 0.1190 - mae: 0.1190
# Epoch 64: val_loss improved from 0.12565 to 0.12535, saving model to model\my_model.h5
# 46/46 [==============================] - 2s 32ms/step - loss: 0.1190 - mae: 0.1190 - val_loss: 0.1253 - val_mae: 0.1253
# Epoch 65/100
# 46/46 [==============================] - ETA: 0s - loss: 0.1188 - mae: 0.1188
# Epoch 65: val_loss improved from 0.12535 to 0.12530, saving model to model\my_model.h5
# 46/46 [==============================] - 1s 23ms/step - loss: 0.1188 - mae: 0.1188 - val_loss: 0.1253 - val_mae: 0.1253
# Epoch 66/100
# 44/46 [===========================>..] - ETA: 0s - loss: 0.1184 - mae: 0.1184
# Epoch 66: val_loss did not improve from 0.12530
# 46/46 [==============================] - 2s 25ms/step - loss: 0.1187 - mae: 0.1187 - val_loss: 0.1255 - val_mae: 0.1255
# Epoch 67/100
# 43/46 [===========================>..] - ETA: 0s - loss: 0.1179 - mae: 0.1179
# Epoch 67: val_loss improved from 0.12530 to 0.12519, saving model to model\my_model.h5
# 46/46 [==============================] - 2s 24ms/step - loss: 0.1181 - mae: 0.1181 - val_loss: 0.1252 - val_mae: 0.1252
# Epoch 68/100
# 44/46 [===========================>..] - ETA: 0s - loss: 0.1183 - mae: 0.1183
# Epoch 68: val_loss improved from 0.12519 to 0.12515, saving model to model\my_model.h5
# 46/46 [==============================] - 2s 30ms/step - loss: 0.1183 - mae: 0.1183 - val_loss: 0.1252 - val_mae: 0.1252
# Epoch 69/100
# 45/46 [============================>.] - ETA: 0s - loss: 0.1179 - mae: 0.1179
# Epoch 69: val_loss improved from 0.12515 to 0.12505, saving model to model\my_model.h5
# 46/46 [==============================] - 1s 18ms/step - loss: 0.1179 - mae: 0.1179 - val_loss: 0.1251 - val_mae: 0.1251
# Epoch 70/100
# 45/46 [============================>.] - ETA: 0s - loss: 0.1176 - mae: 0.1176
# Epoch 70: val_loss improved from 0.12505 to 0.12493, saving model to model\my_model.h5
# 46/46 [==============================] - 1s 19ms/step - loss: 0.1176 - mae: 0.1176 - val_loss: 0.1249 - val_mae: 0.1249
# Epoch 71/100
# 44/46 [===========================>..] - ETA: 0s - loss: 0.1176 - mae: 0.1176
# Epoch 71: val_loss did not improve from 0.12493
# 46/46 [==============================] - 1s 17ms/step - loss: 0.1176 - mae: 0.1176 - val_loss: 0.1250 - val_mae: 0.1250
# Epoch 72/100
# 44/46 [===========================>..] - ETA: 0s - loss: 0.1175 - mae: 0.1175
# Epoch 72: val_loss improved from 0.12493 to 0.12488, saving model to model\my_model.h5
# 46/46 [==============================] - 1s 17ms/step - loss: 0.1176 - mae: 0.1176 - val_loss: 0.1249 - val_mae: 0.1249
# Epoch 73/100
# 42/46 [==========================>...] - ETA: 0s - loss: 0.1175 - mae: 0.1175
# Epoch 73: val_loss improved from 0.12488 to 0.12485, saving model to model\my_model.h5
# 46/46 [==============================] - 1s 17ms/step - loss: 0.1172 - mae: 0.1172 - val_loss: 0.1249 - val_mae: 0.1249
# Epoch 74/100
# 43/46 [===========================>..] - ETA: 0s - loss: 0.1173 - mae: 0.1173
# Epoch 74: val_loss did not improve from 0.12485
# 46/46 [==============================] - 1s 16ms/step - loss: 0.1171 - mae: 0.1171 - val_loss: 0.1249 - val_mae: 0.1249
# Epoch 75/100
# 42/46 [==========================>...] - ETA: 0s - loss: 0.1169 - mae: 0.1169
# Epoch 75: val_loss improved from 0.12485 to 0.12450, saving model to model\my_model.h5
# 46/46 [==============================] - 1s 18ms/step - loss: 0.1169 - mae: 0.1169 - val_loss: 0.1245 - val_mae: 0.1245
# Epoch 76/100
# 46/46 [==============================] - ETA: 0s - loss: 0.1167 - mae: 0.1167
# Epoch 76: val_loss improved from 0.12450 to 0.12448, saving model to model\my_model.h5
# 46/46 [==============================] - 1s 17ms/step - loss: 0.1167 - mae: 0.1167 - val_loss: 0.1245 - val_mae: 0.1245
# Epoch 77/100
# 45/46 [============================>.] - ETA: 0s - loss: 0.1166 - mae: 0.1166
# Epoch 77: val_loss did not improve from 0.12448
# 46/46 [==============================] - 1s 16ms/step - loss: 0.1166 - mae: 0.1166 - val_loss: 0.1247 - val_mae: 0.1247
# Epoch 78/100
# 44/46 [===========================>..] - ETA: 0s - loss: 0.1166 - mae: 0.1166
# Epoch 78: val_loss improved from 0.12448 to 0.12440, saving model to model\my_model.h5
# 46/46 [==============================] - 1s 17ms/step - loss: 0.1165 - mae: 0.1165 - val_loss: 0.1244 - val_mae: 0.1244
# Epoch 79/100
# 44/46 [===========================>..] - ETA: 0s - loss: 0.1166 - mae: 0.1166
# Epoch 79: val_loss improved from 0.12440 to 0.12440, saving model to model\my_model.h5
# 46/46 [==============================] - 1s 17ms/step - loss: 0.1165 - mae: 0.1165 - val_loss: 0.1244 - val_mae: 0.1244
# Epoch 80/100
# 46/46 [==============================] - ETA: 0s - loss: 0.1162 - mae: 0.1162
# Epoch 80: val_loss did not improve from 0.12440
# 46/46 [==============================] - 1s 16ms/step - loss: 0.1162 - mae: 0.1162 - val_loss: 0.1244 - val_mae: 0.1244
# Epoch 81/100
# 44/46 [===========================>..] - ETA: 0s - loss: 0.1162 - mae: 0.1162
# Epoch 81: val_loss improved from 0.12440 to 0.12437, saving model to model\my_model.h5
# 46/46 [==============================] - 1s 17ms/step - loss: 0.1162 - mae: 0.1162 - val_loss: 0.1244 - val_mae: 0.1244
# Epoch 82/100
# 44/46 [===========================>..] - ETA: 0s - loss: 0.1158 - mae: 0.1158
# Epoch 82: val_loss improved from 0.12437 to 0.12436, saving model to model\my_model.h5
# 46/46 [==============================] - 1s 17ms/step - loss: 0.1159 - mae: 0.1159 - val_loss: 0.1244 - val_mae: 0.1244
# Epoch 83/100
# 43/46 [===========================>..] - ETA: 0s - loss: 0.1161 - mae: 0.1161
# Epoch 83: val_loss improved from 0.12436 to 0.12416, saving model to model\my_model.h5
# 46/46 [==============================] - 1s 17ms/step - loss: 0.1159 - mae: 0.1159 - val_loss: 0.1242 - val_mae: 0.1242
# Epoch 84/100
# 45/46 [============================>.] - ETA: 0s - loss: 0.1157 - mae: 0.1157
# Epoch 84: val_loss did not improve from 0.12416
# 46/46 [==============================] - 1s 20ms/step - loss: 0.1158 - mae: 0.1158 - val_loss: 0.1242 - val_mae: 0.1242
# Epoch 85/100
# 42/46 [==========================>...] - ETA: 0s - loss: 0.1155 - mae: 0.1155
# Epoch 85: val_loss did not improve from 0.12416
# 46/46 [==============================] - 1s 16ms/step - loss: 0.1155 - mae: 0.1155 - val_loss: 0.1242 - val_mae: 0.1242
# Epoch 86/100
# 44/46 [===========================>..] - ETA: 0s - loss: 0.1157 - mae: 0.1157
# Epoch 86: val_loss improved from 0.12416 to 0.12415, saving model to model\my_model.h5
# 46/46 [==============================] - 1s 19ms/step - loss: 0.1157 - mae: 0.1157 - val_loss: 0.1241 - val_mae: 0.1242
# Epoch 87/100
# 46/46 [==============================] - ETA: 0s - loss: 0.1155 - mae: 0.1155
# Epoch 87: val_loss did not improve from 0.12415
# 46/46 [==============================] - 1s 16ms/step - loss: 0.1155 - mae: 0.1155 - val_loss: 0.1243 - val_mae: 0.1243
# Epoch 88/100
# 45/46 [============================>.] - ETA: 0s - loss: 0.1153 - mae: 0.1153
# Epoch 88: val_loss improved from 0.12415 to 0.12381, saving model to model\my_model.h5
# 46/46 [==============================] - 1s 17ms/step - loss: 0.1153 - mae: 0.1153 - val_loss: 0.1238 - val_mae: 0.1238
# Epoch 89/100
# 45/46 [============================>.] - ETA: 0s - loss: 0.1155 - mae: 0.1155
# Epoch 89: val_loss did not improve from 0.12381
# 46/46 [==============================] - 1s 15ms/step - loss: 0.1154 - mae: 0.1154 - val_loss: 0.1241 - val_mae: 0.1241
# Epoch 90/100
# 44/46 [===========================>..] - ETA: 0s - loss: 0.1150 - mae: 0.1150
# Epoch 90: val_loss did not improve from 0.12381
# 46/46 [==============================] - 1s 16ms/step - loss: 0.1150 - mae: 0.1150 - val_loss: 0.1239 - val_mae: 0.1239
# Epoch 91/100
# 43/46 [===========================>..] - ETA: 0s - loss: 0.1151 - mae: 0.1151
# Epoch 91: val_loss improved from 0.12381 to 0.12373, saving model to model\my_model.h5
# 46/46 [==============================] - 1s 20ms/step - loss: 0.1151 - mae: 0.1151 - val_loss: 0.1237 - val_mae: 0.1237
# Epoch 92/100
# 46/46 [==============================] - ETA: 0s - loss: 0.1151 - mae: 0.1151
# Epoch 92: val_loss did not improve from 0.12373
# 46/46 [==============================] - 1s 20ms/step - loss: 0.1151 - mae: 0.1151 - val_loss: 0.1238 - val_mae: 0.1238
# Epoch 93/100
# 46/46 [==============================] - ETA: 0s - loss: 0.1148 - mae: 0.1148
# Epoch 93: val_loss did not improve from 0.12373
# 46/46 [==============================] - 1s 16ms/step - loss: 0.1148 - mae: 0.1148 - val_loss: 0.1237 - val_mae: 0.1237
# Epoch 94/100
# 43/46 [===========================>..] - ETA: 0s - loss: 0.1150 - mae: 0.1150
# Epoch 94: val_loss improved from 0.12373 to 0.12359, saving model to model\my_model.h5
# 46/46 [==============================] - 1s 18ms/step - loss: 0.1149 - mae: 0.1149 - val_loss: 0.1236 - val_mae: 0.1236
# Epoch 95/100
# 45/46 [============================>.] - ETA: 0s - loss: 0.1149 - mae: 0.1149
# Epoch 95: val_loss did not improve from 0.12359
# 46/46 [==============================] - 1s 18ms/step - loss: 0.1150 - mae: 0.1150 - val_loss: 0.1236 - val_mae: 0.1236
# Epoch 96/100
# 45/46 [============================>.] - ETA: 0s - loss: 0.1146 - mae: 0.1146
# Epoch 96: val_loss improved from 0.12359 to 0.12356, saving model to model\my_model.h5
# 46/46 [==============================] - 1s 17ms/step - loss: 0.1146 - mae: 0.1146 - val_loss: 0.1236 - val_mae: 0.1236
# Epoch 97/100
# 44/46 [===========================>..] - ETA: 0s - loss: 0.1145 - mae: 0.1145
# Epoch 97: val_loss did not improve from 0.12356
# 46/46 [==============================] - 1s 18ms/step - loss: 0.1146 - mae: 0.1146 - val_loss: 0.1236 - val_mae: 0.1236
# Epoch 98/100
# 44/46 [===========================>..] - ETA: 0s - loss: 0.1145 - mae: 0.1145
# Epoch 98: val_loss improved from 0.12356 to 0.12349, saving model to model\my_model.h5
# 46/46 [==============================] - 1s 19ms/step - loss: 0.1144 - mae: 0.1144 - val_loss: 0.1235 - val_mae: 0.1235
# Epoch 99/100
# 45/46 [============================>.] - ETA: 0s - loss: 0.1146 - mae: 0.1146
# Epoch 99: val_loss improved from 0.12349 to 0.12338, saving model to model\my_model.h5
# 46/46 [==============================] - 2s 24ms/step - loss: 0.1145 - mae: 0.1145 - val_loss: 0.1234 - val_mae: 0.1234
# Epoch 100/100
# 43/46 [===========================>..] - ETA: 0s - loss: 0.1141 - mae: 0.1141
# Epoch 100: val_loss improved from 0.12338 to 0.12326, saving model to model\my_model.h5
# 46/46 [==============================] - 1s 17ms/step - loss: 0.1141 - mae: 0.1141 - val_loss: 0.1233 - val_mae: 0.1233

# %% [markdown]
# # Evaluations

# %%
# Load the pre-trained model from the specified file path
model.load_weights(cp_path)

# %%
model.evaluate(valid_set)
# Out:
# 12/12 [==============================] - 0s 9ms/step - loss: 0.1233 - mae: 0.1233
# [0.12326119095087051, 0.12326119095087051]

# %%
# Visualisasi evaluasi pelatihan
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss (MAE)')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid(True)
plt.show()
